# %% [markdown]
# # Convolution Image Kernel

# %%
import numpy as np
import PIL.Image as pilimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = pilimg.open('space.png')
image.show()

# %%
image = np.array(image)
plt.imshow(image)
plt.show()

# %%
image.shape
# Out:
# (648, 1152, 3)

# %%
plt.imshow(image * 2)
plt.show()

# %%
plt.imshow(image // 2)
plt.show()

# %%
image[0]
# Out:
# array([[190,  65,  11],
#        [190,  65,  11],
#        [185,  60,   6],
#        ...,
#        [ 51,  52,  82],
#        [ 50,  51,  79],
#        [ 51,  48,  75]], dtype=uint8)

# %%
kernel = np.array([[0, 1, 0],
                   [1, -4, 1],
                   [0, 1, 0]])

# %%
z = np.zeros_like(image[0])

# %%
image[0]
# Out:
# array([[190,  65,  11],
#        [190,  65,  11],
#        [185,  60,   6],
#        ...,
#        [ 51,  52,  82],
#        [ 50,  51,  79],
#        [ 51,  48,  75]], dtype=uint8)

# %%
z[1:-1,1] =
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
image[0].shape
# Out:
# (1152, 3)

# %%
test = np.array([[15, 20, 45],
                [70, 255, 17],
                [80, 99, 163],
                [34, 26, 90],
                [90, 55, 198]])
plt.imshow(test)
plt.show()

# %%
test
# Out:
# array([[ 15,  20,  45],
#        [ 70, 255,  17],
#        [ 80,  99, 163],
#        [ 34,  26,  90],
#        [ 90,  55, 198]])

# %%
kernel
# Out:
# array([[ 0,  1,  0],
#        [ 1, -4,  1],
#        [ 0,  1,  0]])

# %%
np.concatenate((
    sum(test[:3,:] * kernel),
    sum(test[1:4,:] * kernel),
    sum(test[2:5,:] * kernel)), axis=0)
# Out:
# array([  70, -901,   17,   80, -115,  163,   34,   50,   90])

# %%
test[:3,:] * kernel
# Out:
# array([[    0,    20,     0],
#        [   70, -1020,    17],
#        [    0,    99,     0]])

# %%
sum((test[:3,:] * kernel).flatten())
# Out:
# -814
