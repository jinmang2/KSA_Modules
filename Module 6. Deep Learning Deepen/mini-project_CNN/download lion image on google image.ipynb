# %%
from google_images_download import google_images_download

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def imageCrawling(keyword, dir_):
    response = google_images_download.googleimagesdownload()
    arguments = {
        'keywords' : keyword,
        'limit' : 100,
        'print_urls' : True,
        'no_directory' : True,
        'output_directory' : dir_
    }
    paths = response.download(arguments)
    print(paths)

# %%
imageCrawling('Lion', './Lion')
# Out:
# Item no.: 1 --> Item name = Lion
# Evaluating...
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/7/73/Lion_waiting_in_Namibia.jpg
# Completed Image ====> 1.Lion_waiting_in_Namibia.jpg
# Image URL: https://timedotcom.files.wordpress.com/2018/12/lion-conservators-center.jpg
# Completed Image ====> 2.lion-conservators-center.jpg
# Image URL: http://www.krugerpark.co.za/images/1-lion-charge-gc590a.jpg
# Completed Image ====> 3.1-lion-charge-gc590a.jpg
# Image URL: https://nationalzoo.si.edu/sites/default/files/animals/africanlion-005_0.jpg
# Completed Image ====> 4.africanlion-005_0.jpg
# Image URL: http://cdn.24.co.za/files/Cms/General/d/8439/fe2bd3548bb44867b2534a083d8d6849.jpg
# Completed Image ====> 5.fe2bd3548bb44867b2534a083d8d6849.jpg
# Image URL: https://conservationaction.co.za/wp-content/uploads/2018/08/CHAS1066.jpg
# Completed Image ====> 6.CHAS1066.jpg
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

keyword = 'Lion'

google_crawler = GoogleImageCrawler(storage={'root_dir': keyword})
google_crawler.crawl(keyword=keyword, max_num=100)

# %%
from icrawler.builtin import GoogleImageCrawler

keyword = 'African lion'

google_crawler = GoogleImageCrawler(
    feeder_threads=1,
    parser_threads=2,
    downloader_threads=4,
    storage={'root_dir': keyword})
filters = dict(
    size='large',
    color='orange',
    license='commercial,modify',
    date=((2016, 1, 1), (2018, 11, 30)))
google_crawler.crawl(keyword=keyword, filters=filters, max_num=3000, file_idx_offset=0)
# Out:
# 2019-07-17 17:24:15,497 - WARNING - icrawler.crawler - Due to Google's limitation, you can only get the first 1000 result. "max_num" has been automatically set to 1000. If you really want to get more than 1000 results, you can specify different date ranges.
# 2019-07-17 17:24:15,498 - INFO - icrawler.crawler - start crawling...
# 2019-07-17 17:24:15,498 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-07-17 17:24:15,500 - INFO - icrawler.crawler - starting 2 parser threads...
# 2019-07-17 17:24:15,505 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2019-07-17 17:24:15,587 - INFO - parser - parser-001 is waiting for new page urls
# 2019-07-17 17:24:15,587 - INFO - parser - parser-001 is waiting for new page urls
# 2019-07-17 17:24:15,587 - INFO - parser - parser-002 is waiting for new page urls
# 2019-07-17 17:24:15,587 - INFO - parser - parser-002 is waiting for new page urls
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

keyword = 'male lion'

google_crawler = GoogleImageCrawler(
    feeder_threads=1,
    parser_threads=2,
    downloader_threads=4,
    storage={'root_dir': keyword})
filters = dict(
    size='large',
    color='orange',
    license='commercial,modify',
    date=((2016, 1, 1), (2018, 11, 30)))
google_crawler.crawl(keyword=keyword, filters=filters, max_num=3000, file_idx_offset=0)
# Out:
# 2019-07-17 18:34:13,546 - WARNING - icrawler.crawler - Due to Google's limitation, you can only get the first 1000 result. "max_num" has been automatically set to 1000. If you really want to get more than 1000 results, you can specify different date ranges.
# 2019-07-17 18:34:13,547 - INFO - icrawler.crawler - start crawling...
# 2019-07-17 18:34:13,547 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-07-17 18:34:13,549 - INFO - icrawler.crawler - starting 2 parser threads...
# 2019-07-17 18:34:13,554 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2019-07-17 18:34:13,584 - INFO - downloader - downloader-002 is waiting for new download tasks
# 2019-07-17 18:34:13,978 - INFO - parser - parser-001 is waiting for new page urls
# 2019-07-17 18:34:13,979 - INFO - parser - parser-002 is waiting for new page urls
# 2019-07-17 18:34:14,068 - INFO - downloader - downloader-002 is waiting for new download tasks
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

keyword = 'national geographic lion'

google_crawler = GoogleImageCrawler(
    feeder_threads=1,
    parser_threads=2,
    downloader_threads=4,
    storage={'root_dir': keyword})
filters = dict(
    size='large',
    color='orange',
    license='commercial,modify',
    date=((2016, 1, 1), (2018, 11, 30)))
google_crawler.crawl(keyword=keyword, filters=filters, max_num=3000, file_idx_offset=0)
# Out:
# 2019-07-17 19:34:37,017 - WARNING - icrawler.crawler - Due to Google's limitation, you can only get the first 1000 result. "max_num" has been automatically set to 1000. If you really want to get more than 1000 results, you can specify different date ranges.
# 2019-07-17 19:34:37,018 - INFO - icrawler.crawler - start crawling...
# 2019-07-17 19:34:37,019 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-07-17 19:34:37,021 - INFO - icrawler.crawler - starting 2 parser threads...
# 2019-07-17 19:34:37,026 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2019-07-17 19:34:37,267 - INFO - parser - parser-001 is waiting for new page urls
# 2019-07-17 19:34:37,269 - INFO - parser - parser-001 is waiting for new page urls
# 2019-07-17 19:34:37,282 - INFO - parser - parser-002 is waiting for new page urls
# 2019-07-17 19:34:37,338 - INFO - parser - parser-001 is waiting for new page urls
# ...

# %%
1. 원본 이미지 샘플 보여주기
2. 데이터 구조 설명
3. 모델 설계
4. 결과
5. 유명한 모델 적용 비교
