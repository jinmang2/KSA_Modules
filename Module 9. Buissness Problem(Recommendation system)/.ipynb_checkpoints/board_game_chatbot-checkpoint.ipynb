# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = './boardgamegeek-reviews/'
games = pd.read_csv(path + '2019-05-02.csv')

# %%
games.describe()
# Out:
#                   ID          Year          Rank       Average  Bayes average  \
# count   17065.000000  17065.000000  17065.000000  17065.000000   17065.000000
# mean    86456.272781   1985.452212   8533.000000      6.352151       5.697914
# std     84274.493113    190.152024   4926.385507      0.914175       0.379697
# min         1.000000      0.000000      1.000000      1.050000       3.471000
# 25%      8374.000000   1999.000000   4267.000000      5.780000       5.511000
# 50%     41898.000000   2009.000000   8533.000000      6.380000       5.556000
# 75%    163154.000000   2015.000000  12799.000000      6.960000       5.702000
# max    272409.000000   3500.000000  17065.000000      9.600000       8.611000
#
#         Users rated
# count  17065.000000
# mean     772.069792
# std     3057.512484
# min       30.000000
# 25%       55.000000
# 50%      118.000000
# 75%      369.000000
# max    84736.000000

# %%
games = games.sort_values('Users rated', ascending=False)
games = games.rename(index=str, columns={"Bayes average": "Geekscore",'Name':'name'})
games.head(10)
# Out:
#          ID            name  Year  Rank  Average  Geekscore  Users rated  \
# 320      13           Catan  1995   321     7.19      7.038        84736
# 149     822     Carcassonne  2000   150     7.43      7.322        84425
# 74    30549        Pandemic  2008    75     7.64      7.546        82770
# 44    68448       7 Wonders  2010    45     7.78      7.690        68569
# 75    36218        Dominion  2008    76     7.65      7.546        67921
# 139    9209  Ticket to Ride  2004   140     7.45      7.345        60151
# 24    31260        Agricola  2007    25     7.99      7.887        56793
# 20     3076     Puerto Rico  2002    21     8.04      7.921        56238
# 205   40692     Small World  2009   206     7.30      7.215        53321
# 58   178900       Codenames  2015    59     7.72      7.625        50564
#
#                               URL  \
# 320           /boardgame/13/catan
# 149    /boardgame/822/carcassonne
# 74      /boardgame/30549/pandemic
# 44     /boardgame/68448/7-wonders
# 75      /boardgame/36218/dominion
# 139   /boardgame/9209/ticket-ride
# 24      /boardgame/31260/agricola
# 20    /boardgame/3076/puerto-rico
# 205  /boardgame/40692/small-world
# 58    /boardgame/178900/codenames
#
#                                              Thumbnail
# 320  https://cf.geekdo-images.com/micro/img/e0y6Bog...
# 149  https://cf.geekdo-images.com/micro/img/z0tTaij...
# 74   https://cf.geekdo-images.com/micro/img/0m3-oqB...
# 44   https://cf.geekdo-images.com/micro/img/h-Ejv31...
# 75   https://cf.geekdo-images.com/micro/img/VYp2s2f...
# 139  https://cf.geekdo-images.com/micro/img/2ytp3TG...
# 24   https://cf.geekdo-images.com/micro/img/Snnyt1c...
# 20   https://cf.geekdo-images.com/micro/img/ti5gCF_...
# 205  https://cf.geekdo-images.com/micro/img/TTJkpvN...
# 58   https://cf.geekdo-images.com/micro/img/3Ihe0IB...

# %%
reviews = pd.read_csv(path + 'bgg-13m-reviews.csv', index_col=0)
print(len(reviews))
reviews.head()
# Out:
# C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# 13170073
#           user  rating                                            comment  ID  \
# 0   sidehacker    10.0                                                NaN  13
# 1  Varthlokkur    10.0                                                NaN  13
# 2   dougthonus    10.0  Currently, this sits on my list as my favorite...  13
# 3       cypar7    10.0  I know it says how many plays, but many, many ...  13
# 4      ssmooth    10.0                                                NaN  13
#
#     name
# 0  Catan
# 1  Catan
# 2  Catan
# 3  Catan
# 4  Catan

# %%
plt.hist(reviews.rating, bins=10)
plt.xlabel('rating of review')
plt.ylabel('number of reviews')
plt.grid(True); plt.show()

# %%
detail_data = pd.read_csv(path + 'games_detailed_info.csv', low_memory=False, index_col=0)

# %%
use_col_ind = np.where(detail_data.isnull().sum() / len(detail_data)  < .5)[0]
detailed = detail_data[detail_data.columns[use_col_ind]]
print(len(detailed))
detailed.head()
# Out:
# 17063
#   Board Game Rank  average  averageweight  bayesaverage  \
# 0             327  7.19118         2.3399       7.03556
# 1             151  7.42605         1.9247       7.32084
# 2              74  7.63799         2.4220       7.54432
# 3              45  7.78118         2.3397       7.68858
# 4              76  7.64470         2.3623       7.54296
#
#                                      boardgameartist  \
# 0  ['Volkan Baga', 'Tanja Donner', 'Pete Fenlon',...
# 1  ['Doris Matthäus', 'Anne Pätzke', 'Chris Quill...
# 2  ['Josh Cappel', 'Christian Hanisch', 'Régis Mo...
# 3                ['Antoine Bauza', 'Miguel Coimbra']
# 4  ['Matthias Catrein', 'Julien Delval', 'Tomasz ...
#
#                                    boardgamecategory        boardgamedesigner  \
# 0                                    ['Negotiation']         ['Klaus Teuber']
# 1  ['City Building', 'Medieval', 'Territory Build...   ['Klaus-Jürgen Wrede']
# 2                                        ['Medical']         ['Matt Leacock']
# 3  ['Ancient', 'Card Game', 'City Building', 'Civ...        ['Antoine Bauza']
# 4                          ['Card Game', 'Medieval']  ['Donald X. Vaccarino']
#
#                                      boardgamefamily  \
# 0               ['Catan', 'Promotional Board Games']
# 1                 ['Carcassonne', 'Country: France']
# 2                                       ['Pandemic']
# 3                  ['7 Wonders', 'Tableau Building']
# 4  ['Crowdfunding: Wspieram', 'Dominion', 'Mensa ...
#
#                                    boardgamemechanic  \
# 0  ['Dice Rolling', 'Modular Board', 'Route/Netwo...
# 1  ['Area Control / Area Influence', 'Tile Placem...
# 2  ['Action Point Allowance System', 'Cooperative...
# 3  ['Card Drafting', 'Hand Management', 'Set Coll...
# 4  ['Card Drafting', 'Deck / Pool Building', 'Han...
#
#                                   boardgamepublisher  ...  \
# 0  ['KOSMOS', '999 Games', 'Albi', 'Astrel Games'...  ...
# 1  ['Hans im Glück', '999 Games', 'Albi', 'Bard C...  ...
# 2  ['Z-Man Games, Inc.', '(Unknown)', 'Albi', 'As...  ...
# 3  ['Repos Production', 'ADC Blackfire Entertainm...  ...
# 4  ['Rio Grande Games', '999 Games', 'Albi', 'Bar...  ...
#
#                        suggested_language_dependence  \
# 0  [OrderedDict([('@level', '36'), ('@value', 'No...
# 1  [OrderedDict([('@level', '1'), ('@value', 'No ...
# 2  [OrderedDict([('@level', '21'), ('@value', 'No...
# 3  [OrderedDict([('@level', '1'), ('@value', 'No ...
# 4  [OrderedDict([('@level', '21'), ('@value', 'No...
#
#                                suggested_num_players  \
# 0  [OrderedDict([('@numplayers', '1'), ('result',...
# 1  [OrderedDict([('@numplayers', '1'), ('result',...
# 2  [OrderedDict([('@numplayers', '1'), ('result',...
# 3  [OrderedDict([('@numplayers', '1'), ('result',...
# 4  [OrderedDict([('@numplayers', '1'), ('result',...
#
#                                  suggested_playerage  \
# 0  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 1  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 2  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 3  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 4  [OrderedDict([('@value', '2'), ('@numvotes', '...
#
#                                            thumbnail  trading       type  \
# 0  https://cf.geekdo-images.com/thumb/img/g8LvJsd...     1685  boardgame
# 1  https://cf.geekdo-images.com/thumb/img/kqE4YJS...     1477  boardgame
# 2  https://cf.geekdo-images.com/thumb/img/HEKrtpT...     1977  boardgame
# 3  https://cf.geekdo-images.com/thumb/img/Grz-qM9...     1162  boardgame
# 4  https://cf.geekdo-images.com/thumb/img/iPlTR5c...     1806  boardgame
#
#    usersrated  wanting  wishing  yearpublished
# 0       85332      453     4729           1995
# 1       85052      498     5403           2000
# 2       83486      614     7655           2008
# 3       69132     1029     9464           2010
# 4       68284      571     6703           2008
#
# [5 rows x 35 columns]

# %%
detailed.columns
# Out:
# Index(['Board Game Rank', 'average', 'averageweight', 'bayesaverage',
#        'boardgameartist', 'boardgamecategory', 'boardgamedesigner',
#        'boardgamefamily', 'boardgamemechanic', 'boardgamepublisher',
#        'description', 'id', 'image', 'maxplayers', 'maxplaytime', 'median',
#        'minage', 'minplayers', 'minplaytime', 'numcomments', 'numweights',
#        'owned', 'playingtime', 'primary', 'stddev',
#        'suggested_language_dependence', 'suggested_num_players',
#        'suggested_playerage', 'thumbnail', 'trading', 'type', 'usersrated',
#        'wanting', 'wishing', 'yearpublished'],
#       dtype='object')

# %% [markdown]
# ```
# 'boardgameartist' : Information about creators
# 'boardgamecategory' : BGG category
# 'boardgamedesigner' : Information about creators
# 'boardgamefamily' : Don't know this one, maybe something with expansions
# 'boardgamemechanic' : Details the mechanics the game uses, such as bluffing
# 'boardgamepublisher' : Information about creators
# 'description' : Text description of the game
# 'id' : IMPORTANT the is the unique key
# 'image' : Link to BGG page
# 'maxplayers' : Maximum amount of players the game is playable with
# 'maxplaytime' : Maximal game time
# 'median' : The median score of the game
# 'minage' : The minimal age to play the game
# 'minplayers' : Minimal amount of players the game is playable with
# 'minplaytime' : Minimal game time
# 'numcomments' : AMount of users that have commented on their score
# 'numweights' : Amount of users that have rated the complexity of the game
# 'owned' : The amount of users that own the game
# 'playingtime' : How long the game takesin minutes
# 'primary' : IMPORTANT this is the primary name of the game
# 'stddev' : Standard deviation of the game reviews
# 'suggested_language_dependence' : The suggestions that users have given for easy  the game is to play in different languages
# 'suggested_num_players' : The suggestions that users have given for the optimal number of players
# 'suggested_playerage' : The suggestions that users have given for how old someone needs to be to play
# 'thumbnail' : The link to the BGG game page
# 'trading' : The amount of users that trade this game
# 'type' : Alwayss a boardgame
# 'usersrated' : The amount of reviews. No comment necessary to be counted
# 'wanting' : The amount of users that have this game on their wantlist
# 'wishing' : The amount of users that have this game on their wishlist
# 'yearpublished' : The year the game was published
# ```

# %%
detailed.isnull().sum()
# Out:
# Board Game Rank                     0
# average                             0
# averageweight                       0
# bayesaverage                        0
# boardgameartist                  4913
# boardgamecategory                 184
# boardgamedesigner                 338
# boardgamefamily                  4554
# boardgamemechanic                1564
# boardgamepublisher                  0
# description                         1
# id                                  0
# image                              40
# maxplayers                          0
# maxplaytime                         0
# median                              0
# minage                              0
# minplayers                          0
# minplaytime                         0
# numcomments                         0
# numweights                          0
# owned                               0
# playingtime                         0
# primary                             0
# stddev                              0
# suggested_language_dependence    2867
# suggested_num_players               0
# suggested_playerage              2527
# thumbnail                          40
# trading                             0
# type                                0
# usersrated                          0
# wanting                             0
# wishing                             0
# yearpublished                       0
# dtype: int64

# %%
detailed.T
# Out:
#                                                                            0      \
# Board Game Rank                                                              327
# average                                                                  7.19118
# averageweight                                                             2.3399
# bayesaverage                                                             7.03556
# boardgameartist                ['Volkan Baga', 'Tanja Donner', 'Pete Fenlon',...
# boardgamecategory                                                ['Negotiation']
# boardgamedesigner                                               ['Klaus Teuber']
# boardgamefamily                             ['Catan', 'Promotional Board Games']
# boardgamemechanic              ['Dice Rolling', 'Modular Board', 'Route/Netwo...
# boardgamepublisher             ['KOSMOS', '999 Games', 'Albi', 'Astrel Games'...
# description                    In Catan (formerly The Settlers of Catan), pla...
# id                                                                            13
# image                          https://cf.geekdo-images.com/original/img/A-0y...
# maxplayers                                                                     4
# maxplaytime                                                                  120
# median                                                                         0
# minage                                                                        10
# minplayers                                                                     3
# minplaytime                                                                   60
# numcomments                                                                16330
# numweights                                                                  6866
# owned                                                                     125254
# playingtime                                                                  120
# primary                                                                    Catan
# stddev                                                                   1.47121
# suggested_language_dependence  [OrderedDict([('@level', '36'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/g8LvJsd...
# trading                                                                     1685
# type                                                                   boardgame
# usersrated                                                                 85332
# wanting                                                                      453
# wishing                                                                     4729
# yearpublished                                                               1995
#
#                                                                            1      \
# Board Game Rank                                                              151
# average                                                                  7.42605
# averageweight                                                             1.9247
# bayesaverage                                                             7.32084
# boardgameartist                ['Doris Matthäus', 'Anne Pätzke', 'Chris Quill...
# boardgamecategory              ['City Building', 'Medieval', 'Territory Build...
# boardgamedesigner                                         ['Klaus-Jürgen Wrede']
# boardgamefamily                               ['Carcassonne', 'Country: France']
# boardgamemechanic              ['Area Control / Area Influence', 'Tile Placem...
# boardgamepublisher             ['Hans im Glück', '999 Games', 'Albi', 'Bard C...
# description                    Carcassonne is a tile-placement game in which ...
# id                                                                           822
# image                          https://cf.geekdo-images.com/original/img/o4p6...
# maxplayers                                                                     5
# maxplaytime                                                                   45
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     2
# minplaytime                                                                   30
# numcomments                                                                16180
# numweights                                                                  6950
# owned                                                                     121717
# playingtime                                                                   45
# primary                                                              Carcassonne
# stddev                                                                   1.30292
# suggested_language_dependence  [OrderedDict([('@level', '1'), ('@value', 'No ...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/kqE4YJS...
# trading                                                                     1477
# type                                                                   boardgame
# usersrated                                                                 85052
# wanting                                                                      498
# wishing                                                                     5403
# yearpublished                                                               2000
#
#                                                                            2      \
# Board Game Rank                                                               74
# average                                                                  7.63799
# averageweight                                                              2.422
# bayesaverage                                                             7.54432
# boardgameartist                ['Josh Cappel', 'Christian Hanisch', 'Régis Mo...
# boardgamecategory                                                    ['Medical']
# boardgamedesigner                                               ['Matt Leacock']
# boardgamefamily                                                     ['Pandemic']
# boardgamemechanic              ['Action Point Allowance System', 'Cooperative...
# boardgamepublisher             ['Z-Man Games, Inc.', '(Unknown)', 'Albi', 'As...
# description                    In Pandemic, several virulent diseases have br...
# id                                                                         30549
# image                          https://cf.geekdo-images.com/original/img/j-pf...
# maxplayers                                                                     4
# maxplaytime                                                                   45
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     2
# minplaytime                                                                   45
# numcomments                                                                14127
# numweights                                                                  4881
# owned                                                                     123067
# playingtime                                                                   45
# primary                                                                 Pandemic
# stddev                                                                   1.32212
# suggested_language_dependence  [OrderedDict([('@level', '21'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/HEKrtpT...
# trading                                                                     1977
# type                                                                   boardgame
# usersrated                                                                 83486
# wanting                                                                      614
# wishing                                                                     7655
# yearpublished                                                               2008
#
#                                                                            3      \
# Board Game Rank                                                               45
# average                                                                  7.78118
# averageweight                                                             2.3397
# bayesaverage                                                             7.68858
# boardgameartist                              ['Antoine Bauza', 'Miguel Coimbra']
# boardgamecategory              ['Ancient', 'Card Game', 'City Building', 'Civ...
# boardgamedesigner                                              ['Antoine Bauza']
# boardgamefamily                                ['7 Wonders', 'Tableau Building']
# boardgamemechanic              ['Card Drafting', 'Hand Management', 'Set Coll...
# boardgamepublisher             ['Repos Production', 'ADC Blackfire Entertainm...
# description                    You are the leader of one of the 7 great citie...
# id                                                                         68448
# image                          https://cf.geekdo-images.com/original/img/3DP_...
# maxplayers                                                                     7
# maxplaytime                                                                   30
# median                                                                         0
# minage                                                                        10
# minplayers                                                                     2
# minplaytime                                                                   30
# numcomments                                                                11816
# numweights                                                                  4009
# owned                                                                      91037
# playingtime                                                                   30
# primary                                                                7 Wonders
# stddev                                                                   1.27559
# suggested_language_dependence  [OrderedDict([('@level', '1'), ('@value', 'No ...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/Grz-qM9...
# trading                                                                     1162
# type                                                                   boardgame
# usersrated                                                                 69132
# wanting                                                                     1029
# wishing                                                                     9464
# yearpublished                                                               2010
#
#                                                                            4      \
# Board Game Rank                                                               76
# average                                                                   7.6447
# averageweight                                                             2.3623
# bayesaverage                                                             7.54296
# boardgameartist                ['Matthias Catrein', 'Julien Delval', 'Tomasz ...
# boardgamecategory                                      ['Card Game', 'Medieval']
# boardgamedesigner                                        ['Donald X. Vaccarino']
# boardgamefamily                ['Crowdfunding: Wspieram', 'Dominion', 'Mensa ...
# boardgamemechanic              ['Card Drafting', 'Deck / Pool Building', 'Han...
# boardgamepublisher             ['Rio Grande Games', '999 Games', 'Albi', 'Bar...
# description                    (from the back of the box:)&#10;&#10;&quot;You...
# id                                                                         36218
# image                          https://cf.geekdo-images.com/original/img/oN8C...
# maxplayers                                                                     4
# maxplaytime                                                                   30
# median                                                                         0
# minage                                                                        13
# minplayers                                                                     2
# minplaytime                                                                   30
# numcomments                                                                12178
# numweights                                                                  4681
# owned                                                                      88729
# playingtime                                                                   30
# primary                                                                 Dominion
# stddev                                                                   1.42599
# suggested_language_dependence  [OrderedDict([('@level', '21'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/iPlTR5c...
# trading                                                                     1806
# type                                                                   boardgame
# usersrated                                                                 68284
# wanting                                                                      571
# wishing                                                                     6703
# yearpublished                                                               2008
#
#                                                                            5      \
# Board Game Rank                                                              142
# average                                                                  7.44716
# averageweight                                                             1.8629
# bayesaverage                                                             7.34375
# boardgameartist                             ['Cyrille Daujean', 'Julien Delval']
# boardgamecategory                                                     ['Trains']
# boardgamedesigner                                               ['Alan R. Moon']
# boardgamefamily                               ['Country: USA', 'Ticket to Ride']
# boardgamemechanic              ['Card Drafting', 'Hand Management', 'Route/Ne...
# boardgamepublisher             ['Days of Wonder', 'ADC Blackfire Entertainmen...
# description                    With elegantly simple gameplay, Ticket to Ride...
# id                                                                          9209
# image                          https://cf.geekdo-images.com/original/img/bOcA...
# maxplayers                                                                     5
# maxplaytime                                                                   60
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     2
# minplaytime                                                                   30
# numcomments                                                                11178
# numweights                                                                  4267
# owned                                                                      79396
# playingtime                                                                   60
# primary                                                           Ticket to Ride
# stddev                                                                   1.28541
# suggested_language_dependence  [OrderedDict([('@level', '41'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/WRanmC5...
# trading                                                                      750
# type                                                                   boardgame
# usersrated                                                                 60558
# wanting                                                                      671
# wishing                                                                     5350
# yearpublished                                                               2004
#
#                                                                            6      \
# Board Game Rank                                                               25
# average                                                                  7.98857
# averageweight                                                             3.6356
# bayesaverage                                                             7.88432
# boardgameartist                                                ['Klemens Franz']
# boardgamecategory                             ['Animals', 'Economic', 'Farming']
# boardgamedesigner                                              ['Uwe Rosenberg']
# boardgamefamily                ['Agricola', 'Animals: Cattle', 'Animals: Hors...
# boardgamemechanic              ['Area Enclosure', 'Card Drafting', 'Hand Mana...
# boardgamepublisher             ['Lookout Games', '999 Games', 'Brain Games', ...
# description                    Description from BoardgameNews&#10;&#10;In Agr...
# id                                                                         31260
# image                          https://cf.geekdo-images.com/original/img/L-UB...
# maxplayers                                                                     5
# maxplaytime                                                                  150
# median                                                                         0
# minage                                                                        12
# minplayers                                                                     1
# minplaytime                                                                   30
# numcomments                                                                11863
# numweights                                                                  5765
# owned                                                                      68487
# playingtime                                                                  150
# primary                                                                 Agricola
# stddev                                                                   1.56493
# suggested_language_dependence  [OrderedDict([('@level', '31'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/zl48oz7...
# trading                                                                     1189
# type                                                                   boardgame
# usersrated                                                                 57064
# wanting                                                                     1114
# wishing                                                                     9167
# yearpublished                                                               2007
#
#                                                                            7      \
# Board Game Rank                                                               20
# average                                                                   8.0359
# averageweight                                                             3.2887
# bayesaverage                                                             7.91934
# boardgameartist                             ['Harald Lieske', 'Franz Vohwinkel']
# boardgamecategory                       ['City Building', 'Economic', 'Farming']
# boardgamedesigner                                           ['Andreas Seyfarth']
# boardgamefamily                ['Alea Big Box', 'Colonial Theme', 'Country: P...
# boardgamemechanic                                       ['Variable Phase Order']
# boardgamepublisher             ['alea', 'Ravensburger Spieleverlag GmbH', 'Br...
# description                    In Puerto Rico players assume the roles of col...
# id                                                                          3076
# image                          https://cf.geekdo-images.com/original/img/RvdW...
# maxplayers                                                                     5
# maxplaytime                                                                  150
# median                                                                         0
# minage                                                                        12
# minplayers                                                                     3
# minplaytime                                                                   90
# numcomments                                                                11218
# numweights                                                                  5777
# owned                                                                      65642
# playingtime                                                                  150
# primary                                                              Puerto Rico
# stddev                                                                   1.38294
# suggested_language_dependence  [OrderedDict([('@level', '6'), ('@value', 'No ...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/pYFq1Wb...
# trading                                                                     1142
# type                                                                   boardgame
# usersrated                                                                 56538
# wanting                                                                     1009
# wishing                                                                     8212
# yearpublished                                                               2002
#
#                                                                            8      \
# Board Game Rank                                                              208
# average                                                                  7.29949
# averageweight                                                             2.3641
# bayesaverage                                                             7.21262
# boardgameartist                            ['Miguel Coimbra', 'Cyrille Daujean']
# boardgamecategory                  ['Fantasy', 'Fighting', 'Territory Building']
# boardgamedesigner                                          ['Philippe Keyaerts']
# boardgamefamily                                                  ['Small World']
# boardgamemechanic              ['Area Control / Area Influence', 'Area Moveme...
# boardgamepublisher             ['Days of Wonder', 'Asmodee', 'Asterion Press'...
# description                    In Small World, players vie for conquest and c...
# id                                                                         40692
# image                          https://cf.geekdo-images.com/original/img/WvXe...
# maxplayers                                                                     5
# maxplaytime                                                                   80
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     2
# minplaytime                                                                   40
# numcomments                                                                 8721
# numweights                                                                  3010
# owned                                                                      70066
# playingtime                                                                   80
# primary                                                              Small World
# stddev                                                                   1.29849
# suggested_language_dependence  [OrderedDict([('@level', '6'), ('@value', 'No ...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/w1PBg6R...
# trading                                                                     1714
# type                                                                   boardgame
# usersrated                                                                 53620
# wanting                                                                      907
# wishing                                                                     7875
# yearpublished                                                               2009
#
#                                                                            9      \
# Board Game Rank                                                               60
# average                                                                  7.71148
# averageweight                                                             1.3099
# bayesaverage                                                             7.62173
# boardgameartist                ['Stéphane Gantiez', 'Tomáš Kučerovský', 'Fili...
# boardgamecategory              ['Card Game', 'Deduction', 'Party Game', 'Spie...
# boardgamedesigner                                             ['Vlaada Chvátil']
# boardgamefamily                                                    ['Codenames']
# boardgamemechanic                  ['Memory', 'Partnerships', 'Press Your Luck']
# boardgamepublisher             ['Czech Games Edition', 'Bergsala Enigma', 'Bo...
# description                    Two rival spymasters know the secret identitie...
# id                                                                        178900
# image                          https://cf.geekdo-images.com/original/img/MJ6M...
# maxplayers                                                                     8
# maxplaytime                                                                   15
# median                                                                         0
# minage                                                                        14
# minplayers                                                                     2
# minplaytime                                                                   15
# numcomments                                                                 7104
# numweights                                                                  1394
# owned                                                                      80742
# playingtime                                                                   15
# primary                                                                Codenames
# stddev                                                                   1.28379
# suggested_language_dependence  [OrderedDict([('@level', '26'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/jEZ06Ca...
# trading                                                                      752
# type                                                                   boardgame
# usersrated                                                                 51209
# wanting                                                                      345
# wishing                                                                     4365
# yearpublished                                                               2015
#
#                                ...  \
# Board Game Rank                ...
# average                        ...
# averageweight                  ...
# bayesaverage                   ...
# boardgameartist                ...
# boardgamecategory              ...
# boardgamedesigner              ...
# boardgamefamily                ...
# boardgamemechanic              ...
# boardgamepublisher             ...
# description                    ...
# id                             ...
# image                          ...
# maxplayers                     ...
# maxplaytime                    ...
# median                         ...
# minage                         ...
# minplayers                     ...
# minplaytime                    ...
# numcomments                    ...
# numweights                     ...
# owned                          ...
# playingtime                    ...
# primary                        ...
# stddev                         ...
# suggested_language_dependence  ...
# suggested_num_players          ...
# suggested_playerage            ...
# thumbnail                      ...
# trading                        ...
# type                           ...
# usersrated                     ...
# wanting                        ...
# wishing                        ...
# yearpublished                  ...
#
#                                                                            17053  \
# Board Game Rank                                                            11027
# average                                                                  6.81297
# averageweight                                                                  1
# bayesaverage                                                             5.52803
# boardgameartist                                          ['Oliver Freudenreich']
# boardgamecategory                      ['Action / Dexterity', "Children's Game"]
# boardgamedesigner                                               ['Gunter Baars']
# boardgamefamily                                                       ['Circus']
# boardgamemechanic                    ['Pattern Building', 'Pattern Recognition']
# boardgamepublisher                            ['Ravensburger Spieleverlag GmbH']
# description                    Players each have a stack of pieces in three c...
# id                                                                         11466
# image                          https://cf.geekdo-images.com/original/img/IpDQ...
# maxplayers                                                                     4
# maxplaytime                                                                   15
# median                                                                         0
# minage                                                                         5
# minplayers                                                                     2
# minplaytime                                                                   15
# numcomments                                                                   19
# numweights                                                                     3
# owned                                                                         49
# playingtime                                                                   15
# primary                                                        Peppino the Clown
# stddev                                                                   2.16187
# suggested_language_dependence  [OrderedDict([('@level', '21'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/x1jYKJc...
# trading                                                                        1
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                       10
# wishing                                                                       12
# yearpublished                                                               1999
#
#                                                                            17054  \
# Board Game Rank                                                            12970
# average                                                                  5.93333
# averageweight                                                                  1
# bayesaverage                                                             5.51044
# boardgameartist                                                  ['Marek Bláha']
# boardgamecategory                                            ["Children's Game"]
# boardgamedesigner                                  ['Helmut Ast', 'Katrin Kuhr']
# boardgamefamily                                                              NaN
# boardgamemechanic                                                            NaN
# boardgamepublisher                                                     ['HUCH!']
# description                    Game description from the publisher:&#10;&#10;...
# id                                                                        153501
# image                          https://cf.geekdo-images.com/original/img/f0qK...
# maxplayers                                                                     4
# maxplaytime                                                                   20
# median                                                                         0
# minage                                                                         5
# minplayers                                                                     2
# minplaytime                                                                   20
# numcomments                                                                    6
# numweights                                                                     1
# owned                                                                         35
# playingtime                                                                   20
# primary                                                       Mit Mist und Tücke
# stddev                                                                   1.30213
# suggested_language_dependence  [OrderedDict([('@level', '1'), ('@value', 'No ...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/hALfUkB...
# trading                                                                        0
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        1
# wishing                                                                        8
# yearpublished                                                               2014
#
#                                                                            17055  \
# Board Game Rank                                                            12966
# average                                                                  5.88333
# averageweight                                                                  3
# bayesaverage                                                             5.51045
# boardgameartist                                                              NaN
# boardgamecategory                                      ['Novel-based', 'Puzzle']
# boardgamedesigner                   ['Kimberly Coombs', "Wenda O'Reilly, Ph.D."]
# boardgamefamily                                                 ['Harry Potter']
# boardgamemechanic                 ['Dice Rolling', 'Grid Movement', 'Take That']
# boardgamepublisher                                            ['Birdcage Press']
# description                    It's Gryffindor vs. Slytherin in this fast-pac...
# id                                                                        209667
# image                          https://cf.geekdo-images.com/original/img/vwId...
# maxplayers                                                                     2
# maxplaytime                                                                    0
# median                                                                         0
# minage                                                                         7
# minplayers                                                                     2
# minplaytime                                                                    0
# numcomments                                                                   11
# numweights                                                                     1
# owned                                                                         95
# playingtime                                                                    0
# primary                        Golden Snitch: Snitch Snatcher – The Quidditch...
# stddev                                                                  0.997358
# suggested_language_dependence  [OrderedDict([('@level', '41'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/7t6u3xh...
# trading                                                                        2
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        1
# wishing                                                                        7
# yearpublished                                                                  0
#
#                                                                            17056  \
# Board Game Rank                                                       Not Ranked
# average                                                                   6.0869
# averageweight                                                                  1
# bayesaverage                                                                   0
# boardgameartist                                                              NaN
# boardgamecategory                                                            NaN
# boardgamedesigner                                               ['(Uncredited)']
# boardgamefamily                                                              NaN
# boardgamemechanic                                                            NaN
# boardgamepublisher                                       ['Jouets Bo-Jeux Toys']
# description                    From box cover:&#10;Double Series. The challen...
# id                                                                         55686
# image                          https://cf.geekdo-images.com/original/img/PP-T...
# maxplayers                                                                    10
# maxplaytime                                                                    0
# median                                                                         0
# minage                                                                         0
# minplayers                                                                     2
# minplaytime                                                                    0
# numcomments                                                                   10
# numweights                                                                     3
# owned                                                                         74
# playingtime                                                                    0
# primary                                                            Double Series
# stddev                                                                   1.65479
# suggested_language_dependence  [OrderedDict([('@level', '86'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/kCF4Xax...
# trading                                                                        2
# type                                                                   boardgame
# usersrated                                                                    29
# wanting                                                                        1
# wishing                                                                        1
# yearpublished                                                               1996
#
#                                                                            17057  \
# Board Game Rank                                                       Not Ranked
# average                                                                  6.68103
# averageweight                                                                2.4
# bayesaverage                                                                   0
# boardgameartist                                          ['Jaime Iscar Gallego']
# boardgamecategory                                                     ['Sports']
# boardgamedesigner                                        ['Jaime Iscar Gallego']
# boardgamefamily                                    ['Sports: Football / Soccer']
# boardgamemechanic              ['Area Movement', 'Hand Management', 'Simulati...
# boardgamepublisher                                          ['(Self-Published)']
# description                    From the publisher: Football Leader is a simul...
# id                                                                         84017
# image                          https://cf.geekdo-images.com/original/img/vZmj...
# maxplayers                                                                     2
# maxplaytime                                                                  150
# median                                                                         0
# minage                                                                         0
# minplayers                                                                     2
# minplaytime                                                                   90
# numcomments                                                                   12
# numweights                                                                    10
# owned                                                                         40
# playingtime                                                                  150
# primary                                                          Football Leader
# stddev                                                                   1.23291
# suggested_language_dependence  [OrderedDict([('@level', '56'), ('@value', 'No...
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/huO_3Xx...
# trading                                                                        3
# type                                                                   boardgame
# usersrated                                                                    29
# wanting                                                                        2
# wishing                                                                        9
# yearpublished                                                               2010
#
#                                                                            17058  \
# Board Game Rank                                                            12961
# average                                                                  5.93667
# averageweight                                                                  1
# bayesaverage                                                             5.51052
# boardgameartist                                            ['Gabriela Silveira']
# boardgamecategory                                 ['Animals', "Children's Game"]
# boardgamedesigner                            ['Alan R. Moon', 'Aaron Weissblum']
# boardgamefamily                                                              NaN
# boardgamemechanic                                                            NaN
# boardgamepublisher                                         ['Goldsieber Spiele']
# description                    A children's game that appears to involve stac...
# id                                                                         10809
# image                          https://cf.geekdo-images.com/original/img/eUqb...
# maxplayers                                                                     5
# maxplaytime                                                                   20
# median                                                                         0
# minage                                                                         5
# minplayers                                                                     3
# minplaytime                                                                   20
# numcomments                                                                   15
# numweights                                                                     5
# owned                                                                         46
# playingtime                                                                   20
# primary                                                          Immer oben auf!
# stddev                                                                   1.31896
# suggested_language_dependence                                                NaN
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage                                                          NaN
# thumbnail                      https://cf.geekdo-images.com/thumb/img/8ssvEKd...
# trading                                                                        5
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        2
# wishing                                                                        5
# yearpublished                                                               2004
#
#                                                                            17059  \
# Board Game Rank                                                            15499
# average                                                                     4.74
# averageweight                                                              2.375
# bayesaverage                                                             5.47984
# boardgameartist                                                              NaN
# boardgamecategory              ['Civilization', 'Environmental', 'Modern Warf...
# boardgamedesigner                             ['Frank Zuuring', 'Peter Zuuring']
# boardgamefamily                                              ['Antarctic Theme']
# boardgamemechanic              ['Area Movement', 'Campaign / Battle Card Driv...
# boardgamepublisher                                        ['Savita Games, Inc.']
# description                    Global warming has melted the great ice sheets...
# id                                                                         23257
# image                          https://cf.geekdo-images.com/original/img/Ztkm...
# maxplayers                                                                     4
# maxplaytime                                                                  120
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     2
# minplaytime                                                                  120
# numcomments                                                                   31
# numweights                                                                     8
# owned                                                                         57
# playingtime                                                                  120
# primary                                               Antarctica (first edition)
# stddev                                                                   1.86362
# suggested_language_dependence                                                NaN
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage                                                          NaN
# thumbnail                      https://cf.geekdo-images.com/thumb/img/VPIn350...
# trading                                                                        9
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        2
# wishing                                                                       12
# yearpublished                                                               2006
#
#                                                                            17060  \
# Board Game Rank                                                            14315
# average                                                                      5.4
# averageweight                                                                2.5
# bayesaverage                                                             5.49719
# boardgameartist                                                 ['(Uncredited)']
# boardgamecategory                                     ['Adventure', 'Deduction']
# boardgamedesigner                                             ['Thomas Kotulla']
# boardgamefamily                                                              NaN
# boardgamemechanic                                                            NaN
# boardgamepublisher                        ['Clou', 'F.X. Schmid', 'Wendel GmbH']
# description                    This game is set in the Southern American jung...
# id                                                                          9272
# image                          https://cf.geekdo-images.com/original/img/0eVs...
# maxplayers                                                                     6
# maxplaytime                                                                   90
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     2
# minplaytime                                                                   90
# numcomments                                                                   12
# numweights                                                                     2
# owned                                                                        124
# playingtime                                                                   90
# primary                                                               Jade König
# stddev                                                                    1.2741
# suggested_language_dependence                                                NaN
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage                                                          NaN
# thumbnail                      https://cf.geekdo-images.com/thumb/img/w-qK2q5...
# trading                                                                       12
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        2
# wishing                                                                        3
# yearpublished                                                               1986
#
#                                                                            17061  \
# Board Game Rank                                                            14317
# average                                                                      5.8
# averageweight                                                               2.75
# bayesaverage                                                             5.49718
# boardgameartist                                                              NaN
# boardgamecategory                                      ['Napoleonic', 'Wargame']
# boardgamedesigner                                              ['Roger Sandell']
# boardgamefamily                ['Alternate History', 'Country: England', 'Mag...
# boardgamemechanic                                            ['Hex-and-Counter']
# boardgamepublisher                                                  ['XTR Corp']
# description                    (from the game : )&#10;&#10;&quot;Perfidious A...
# id                                                                         13392
# image                          https://cf.geekdo-images.com/original/img/VtFs...
# maxplayers                                                                     2
# maxplaytime                                                                    0
# median                                                                         0
# minage                                                                        12
# minplayers                                                                     2
# minplaytime                                                                    0
# numcomments                                                                   32
# numweights                                                                     4
# owned                                                                        241
# playingtime                                                                    0
# primary                        Perfidious Albion: Napoleon's (Hypothetical) I...
# stddev                                                                   1.84662
# suggested_language_dependence                                                NaN
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage                                                          NaN
# thumbnail                      https://cf.geekdo-images.com/thumb/img/dgf5MIp...
# trading                                                                       12
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        7
# wishing                                                                        6
# yearpublished                                                               1997
#
#                                                                            17062
# Board Game Rank                                                            15543
# average                                                                  4.56667
# averageweight                                                             1.6667
# bayesaverage                                                              5.4791
# boardgameartist                                                              NaN
# boardgamecategory                                        ['Puzzle', 'Word Game']
# boardgamedesigner                                    ['Terry Miller Associates']
# boardgamefamily                                                         ['LEGO']
# boardgamemechanic                               ['Line Drawing', 'Partnerships']
# boardgamepublisher                         ['LEGO', 'RoseArt', 'Warren Company']
# description                    &quot;The LEGO Game of Charades&quot; -- It is...
# id                                                                          8256
# image                          https://cf.geekdo-images.com/original/img/DKOk...
# maxplayers                                                                     6
# maxplaytime                                                                   30
# median                                                                         0
# minage                                                                         8
# minplayers                                                                     3
# minplaytime                                                                   30
# numcomments                                                                   23
# numweights                                                                     3
# owned                                                                         88
# playingtime                                                                   30
# primary                                                LEGO Constructionary Game
# stddev                                                                   1.61624
# suggested_language_dependence                                                NaN
# suggested_num_players          [OrderedDict([('@numplayers', '1'), ('result',...
# suggested_playerage            [OrderedDict([('@value', '2'), ('@numvotes', '...
# thumbnail                      https://cf.geekdo-images.com/thumb/img/k3V6l7k...
# trading                                                                        2
# type                                                                   boardgame
# usersrated                                                                    30
# wanting                                                                        1
# wishing                                                                        5
# yearpublished                                                               1999
#
# [35 rows x 17063 columns]

# %%
detailed.boardgamepublisher[0]
# Out:
# "['KOSMOS', '999 Games', 'Albi', 'Astrel Games', 'Bergsala Enigma', 'Brain Games', 'Capcom Co., Ltd.', 'Catan Studio', 'Competo / Marektoy', 'danspil', 'Descartes Editeur', 'Devir', 'Dexy Co', 'Eurogames', 'Filosofia Éditions', 'Galakta', 'Giochi Uniti', 'GP Games', 'Grow Jogos e Brinquedos', 'HaKubia', 'Hanayama', 'Hobby World', 'Ideal Board Games', 'Igroljub', 'IntelliGames.BG', 'Ísöld ehf.', 'Kaissa Chess & Games', 'Korea Boardgames co., Ltd.', 'L&M Games', 'Laser plus', 'Lautapelit.fi', 'Logojogos', 'Mayfair Games', 'Ninive Games', 'Piatnik', 'Smart Ltd', 'Stupor Mundi', 'Swan Panasia Co., Ltd.', 'Tilsit', 'Top Toys', 'TRY SOFT']"

# %%
detailed.boardgamepublisher[127]
# Out:
# "['Funforge', 'Asterion Press', 'Bergsala Enigma', 'Devir', 'Galápagos Jogos', 'Gém Klub Kft.', 'hobbity.eu', 'Hobby World', 'Jolly Thinkers', 'MINDOK', 'Passport Game Studios', 'Pendragon Game Studio', 'Swan Panasia Co., Ltd.', 'Zhiyanjia']"

# %%
detailed['suggested_num_players'][0]
# Out:
# "[OrderedDict([('@numplayers', '1'), ('result', [OrderedDict([('@value', 'Best'), ('@numvotes', '1')]), OrderedDict([('@value', 'Recommended'), ('@numvotes', '3')]), OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '878')])])]), OrderedDict([('@numplayers', '2'), ('result', [OrderedDict([('@value', 'Best'), ('@numvotes', '10')]), OrderedDict([('@value', 'Recommended'), ('@numvotes', '146')]), OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '796')])])]), OrderedDict([('@numplayers', '3'), ('result', [OrderedDict([('@value', 'Best'), ('@numvotes', '428')]), OrderedDict([('@value', 'Recommended'), ('@numvotes', '715')]), OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '73')])])]), OrderedDict([('@numplayers', '4'), ('result', [OrderedDict([('@value', 'Best'), ('@numvotes', '966')]), OrderedDict([('@value', 'Recommended'), ('@numvotes', '280')]), OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '28')])])]), OrderedDict([('@numplayers', '4+'), ('result', [OrderedDict([('@value', 'Best'), ('@numvotes', '42')]), OrderedDict([('@value', 'Recommended'), ('@numvotes', '134')]), OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '543')])])])]"

# %%
detailed[['minplayers', 'maxplayers']].iloc[0]
# Out:
# minplayers    3
# maxplayers    4
# Name: 0, dtype: int64

# %% [markdown]
# ```
# [
#     OrderedDict(
#         [    ('@numplayers', '1'),
#              ('result', [
#                      OrderedDict([('@value', 'Best'), ('@numvotes', '1')]),
#                      OrderedDict([('@value', 'Recommended'), ('@numvotes', '3')]),
#                      OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '878')])
#                         ])
#          ]),
#     OrderedDict(
#         [    ('@numplayers', '2'),
#              ('result', [
#                      OrderedDict([('@value', 'Best'), ('@numvotes', '10')]),
#                      OrderedDict([('@value', 'Recommended'), ('@numvotes', '146')]),
#                      OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '796')])
#                         ])
#         ]),
#     OrderedDict(
#         [    ('@numplayers', '3'),
#              ('result', [
#                      OrderedDict([('@value', 'Best'), ('@numvotes', '428')]),
#                      OrderedDict([('@value', 'Recommended'), ('@numvotes', '715')]),
#                      OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '73')])
#                         ])
#         ]),
#     OrderedDict(
#         [    ('@numplayers', '4'),
#              ('result', [
#                      OrderedDict([('@value', 'Best'), ('@numvotes', '966')]),
#                      OrderedDict([('@value', 'Recommended'), ('@numvotes', '280')]),
#                      OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '28')])
#                          ])
#               ]),
#     OrderedDict(
#         [    ('@numplayers', '4+'),
#              ('result', [
#                      OrderedDict([('@value', 'Best'), ('@numvotes', '42')]),
#                      OrderedDict([('@value', 'Recommended'), ('@numvotes', '134')]),
#                      OrderedDict([('@value', 'Not Recommended'), ('@numvotes', '543')])
#                          ])
#               ])
# ]
# ```
